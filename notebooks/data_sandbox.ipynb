# %% [markdown]
# Jupyter Notebook Data Sandbox

# %%
# Imports
import pandas as pd

df = pd.read_csv("../../insights-project-v2/data/processed/wvsos_processed.csv", parse_dates=['filing_date', 'termination_date'])
print(df['filing_date'].min(), df['filing_date'].max())
df.head()
# Out:
# 1803-11-25 00:00:00 2109-01-11 00:00:00
#               organization_name         org_type filing_date termination_date  \
# 0         #29 TRUCKING CO. INC.  C | Corporation  1985-04-19       1986-09-11
# 1             A & C CABLE, INC.  C | Corporation  1984-02-01       1989-05-05
# 2  A & C CONSTRUCTION CO., INC.  C | Corporation  1966-09-14       2007-07-06
# 3    A & C REALTY COMPANY, INC.  C | Corporation  1966-03-29       1986-09-11
# 4         A & C TRANSPORT, INC.  C | Corporation  1984-11-09       1991-04-25
#
#   business_purpose  naics charter_state
# 0              NaN    NaN            WV
# 1              NaN    NaN            WV
# 2              NaN    NaN            OH
# 3              NaN    NaN            WV
# 4              NaN    NaN            VA
